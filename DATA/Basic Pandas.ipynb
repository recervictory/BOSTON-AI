# %%
import pandas as pd

# %%
data=pd.read_csv('client.csv',sep=';')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    client_id  birth_number  district_id
# 0          1        706213           18
# 1          2        450204            1
# 2          3        406009            1
# 3          4        561201            5
# 4          5        605703            5

# %%
data.tail()
# Out:
#       client_id  birth_number  district_id
# 5364      13955        456030            1
# 5365      13956        430406            1
# 5366      13968        680413           61
# 5367      13971        626019           67
# 5368      13998        535812           74

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5369 entries, 0 to 5368
# Data columns (total 3 columns):
# client_id       5369 non-null int64
# birth_number    5369 non-null int64
# district_id     5369 non-null int64
# dtypes: int64(3)
# memory usage: 126.0 KB

# %%
data['birth_number']
# Out:
# 0       706213
# 1       450204
# 2       406009
# 3       561201
# 4       605703
#          ...
# 5364    456030
# 5365    430406
# 5366    680413
# 5367    626019
# 5368    535812
# Name: birth_number, Length: 5369, dtype: int64

# %%
type(data['birth_number'])
# Out:
# pandas.core.series.Series

# %%
data[['birth_number','district_id']]
# Out:
#       birth_number  district_id
# 0           706213           18
# 1           450204            1
# 2           406009            1
# 3           561201            5
# 4           605703            5
# ...            ...          ...
# 5364        456030            1
# 5365        430406            1
# 5366        680413           61
# 5367        626019           67
# 5368        535812           74
#
# [5369 rows x 2 columns]

# %% [markdown]
# ###

# %%
import pandas as pd
import numpy as np

# %%
account = pd.read_csv(r'account.csv',sep=";")
account.head()
# Out:
#    account_id  district_id         frequency    date
# 0         576           55  POPLATEK MESICNE  930101
# 1        3818           74  POPLATEK MESICNE  930101
# 2         704           55  POPLATEK MESICNE  930101
# 3        2378           16  POPLATEK MESICNE  930101
# 4        2632           24  POPLATEK MESICNE  930102

# %%
trans = pd.read_csv(r'trans.csv',sep=";",nrows=100000)
trans.head()
# Out:
#    trans_id  account_id    date    type operation  amount  balance k_symbol  \
# 0    695247        2378  930101  PRIJEM     VKLAD   700.0    700.0      NaN
# 1    171812         576  930101  PRIJEM     VKLAD   900.0    900.0      NaN
# 2    207264         704  930101  PRIJEM     VKLAD  1000.0   1000.0      NaN
# 3   1117247        3818  930101  PRIJEM     VKLAD   600.0    600.0      NaN
# 4    579373        1972  930102  PRIJEM     VKLAD   400.0    400.0      NaN
#
#   bank  account
# 0  NaN      NaN
# 1  NaN      NaN
# 2  NaN      NaN
# 3  NaN      NaN
# 4  NaN      NaN

# %%
pd.merge(account,trans,how='right')
# Out:
#        account_id  district_id         frequency    date  trans_id    type  \
# 0            2378         16.0  POPLATEK MESICNE  930101    695247  PRIJEM
# 1             576         55.0  POPLATEK MESICNE  930101    171812  PRIJEM
# 2             704         55.0  POPLATEK MESICNE  930101    207264  PRIJEM
# 3            3818         74.0  POPLATEK MESICNE  930101   1117247  PRIJEM
# 4            1972         77.0  POPLATEK MESICNE  930102    579373  PRIJEM
# ...           ...          ...               ...     ...       ...     ...
# 99995        1604          NaN               NaN  941031   3583101  PRIJEM
# 99996        1601          NaN               NaN  941031   3582914  PRIJEM
# 99997        1666          NaN               NaN  941031   3585094  PRIJEM
# 99998        1579          NaN               NaN  941031   3582250  PRIJEM
# 99999        1603          NaN               NaN  941031   3583041  PRIJEM
#
#       operation  amount  balance k_symbol bank  account
# ...
